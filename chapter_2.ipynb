# %% [markdown]
# <a href="https://colab.research.google.com/github/jeremysb1/grokking-statistics/blob/main/chapter_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
collie_weights = np.array([51.2,53.1,53.1,53.9,59.0,
   59.3,60.2,61.1,67.2,67.6])

# %%
collie_weight_mean = np.mean(collie_weights)

# %%
print("Collie Weight Mean (lbs):", collie_weight_mean)
# Out:
# Collie Weight Mean (lbs): 58.57000000000001

# %%
# Three exams and a final score
exam_scores = [85, 90, 88, 92]

# %%
# Weighting for each exam
weights = [.2, .2, .2, .4]

# %%
# Calculate weighted average
weighted_average = sum(e*w for e, w in zip(exam_scores, weights)) / sum(weights)

# %%
print("Final grade: ", weighted_average)
# Out:
# Final grade:  89.4

# %%
print("Using NumPy: ", np.average(exam_scores, weights=weights))
# Out:
# Using NumPy:  89.4

# %%
bar_tabs = [7, 18, 19, 20, 21, 22, 25, 120, 1500]

# %%
mean = np.mean(bar_tabs)
median = np.median(bar_tabs)

# %%
print("Mean: ", mean)
print("Median: ", median)
# Out:
# Mean:  194.66666666666666
# Median:  21.0

# %%
# percentiles

q25 = np.percentile(bar_tabs, 25)
q50 = np.percentile(bar_tabs, 50)
q75 = np.percentile(bar_tabs, 75)

print(q25, q50, q75)
# Out:
# 19.0 21.0 25.0

# %%
# mode

from scipy import stats
group_sizes = np.array([2, 4, 2, 3, 6, 2, 5, 4, 2, 3, 2])

result = stats.mode(group_sizes)

# %%
print(f"MODE: {result.mode}, COUNT: {result.count}")
# Out:
# MODE: 2, COUNT: 5

# %%
temps = [77,75,68,71,60,65,81,71,56,73,
       79,80,85,84,72,69,82,81,71,63,
       75,83,80,80,88,76,79,73,80,81,82]

# %%
mean = np.mean(temps)

# %%
print("MIN: ", np.min(temps), "MAX: ", np.max(temps))
# Out:
# MIN:  56 MAX:  88

# %%
print("MEAN: ", mean)
# Out:
# MEAN:  75.48387096774194

# %%
print("MEDIAN: ", np.median(temps))
# Out:
# MEDIAN:  77.0

# %%
# sum all the squared differences
squared_diffs = 0
for t in temps:
    squared_diffs += (t - mean) ** 2

# %%
# take the avg of the squared differences
variance = squared_diffs / (len(temps) - 1)

print("Variance: ", variance)
# Out:
# Variance:  57.65806451612904

# %%
from math import sqrt

def variance(data: [int]):
  mean = sum(data) / len(data)

  squared_diffs = 0
  for x in data:
      squared_diffs += (x - mean) ** 2

  return squared_diffs / (len(data) - 1)

def standard_deviation(data: [int]):
  return sqrt(variance(data))

print("Standard Deviation: ", standard_deviation(temps))
# Out:
# Standard Deviation:  7.5932907567226104

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/thomasnield/"
      "training-data-repository/refs/heads/main/TORNADO_TRX.csv")

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3210 entries, 0 to 3209
# Data columns (total 36 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   EVENT_ID             3210 non-null   int64
#  1   CZ_NAME_STR          3210 non-null   object
#  2   BEGIN_DATETIME       3210 non-null   object
#  3   END_DATETIME         3210 non-null   object
#  4   BEGIN_LOCATION       3210 non-null   object
#  5   EVENT_TYPE           3210 non-null   object
#  6   MAGNITUDE            3210 non-null   object
#  7   TOR_F_SCALE          3210 non-null   object
#  8   DEATHS_DIRECT        3210 non-null   int64
#  9   INJURIES_DIRECT      3210 non-null   int64
#  10  DAMAGE_PROPERTY_NUM  3210 non-null   int64
#  11  DAMAGE_CROPS_NUM     3210 non-null   int64
#  12  STATE_ABBR           3210 non-null   object
#  13  CZ_TIMEZONE          3210 non-null   object
#  14  MAGNITUDE_TYPE       3210 non-null   object
# ...

# %%
import matplotlib.pyplot as plt
df = pd.read_csv("https://raw.githubusercontent.com/thomasnield/"
              "training-data-repository/refs/heads/main/TORNADO_TRX.csv")

# %%
tor_width = df['TOR_WIDTH']

# %%
print("MEAN: ", np.mean(tor_width))
print("MEDIAN: ", np.median(tor_width))
print("ST DEV: ", np.std(tor_width, ddof=1))
# Out:
# MEAN:  215.18971962616823
# MEDIAN:  100.0
# ST DEV:  315.83093225491456

# %%
print("25th PCT: ", np.percentile(tor_width, 25))
print("75th PCT: ", np.percentile(tor_width, 75))
# Out:
# 25th PCT:  50.0
# 75th PCT:  250.0

# %%
print(df['TOR_F_SCALE'].value_counts())
# Out:
# TOR_F_SCALE
# EF1    1250
# EF0    1047
# EFU     497
# EF2     323
# EF3      86
# EF4       7
# Name: count, dtype: int64

# %%
plt.hist(tor_width, bins=60, edgecolor='black')
plt.title('Histogram of Tornado Width')
plt.xlabel('Width')
plt.ylabel('Frequency')
plt.grid(True, alpha=0.3)
plt.show()

# %%
grouped_stats = df.groupby('TOR_F_SCALE')['TOR_WIDTH'].agg(
    p25=lambda x: np.percentile(x, 25),
    median='median',
    p75=lambda x: np.percentile(x, 75),
    iqr=lambda x: np.percentile(x, 75) - np.percentile(x, 25)
).reset_index()

# %%
grouped_stats = grouped_stats.round(2)

# %%
print("TOR_WIDTH Statistics by TOR_F_SCALE:")
print(grouped_stats)
# Out:
# TOR_WIDTH Statistics by TOR_F_SCALE:
#   TOR_F_SCALE     p25  median     p75    iqr
# 0         EF0    30.0    50.0   100.0   70.0
# 1         EF1    80.0   150.0   300.0  220.0
# 2         EF2   200.0   400.0   792.5  592.5
# 3         EF3   400.0   700.0  1387.5  987.5
# 4         EF4  1000.0  1320.0  1575.0  575.0
# 5         EFU    20.0    30.0    50.0   30.0
